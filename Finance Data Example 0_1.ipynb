# %%
'''
Alphavantage is a Y-combinator backed start-up providing free and priced premium financial data 

https://www.alphavantage.co/documentation/#
'''
# KA3WLMAG53VKX67 
APIKEY="A3WLMAG53VKX67"

# %%
import csv
import requests

# %%
url = 'https://www.alphavantage.co/query?function=CPI&interval=monthly&apikey=A3WLMAG53VKX67'
r = requests.get(url)
inflation_data = r.json()

print(inflation_data)
# Out:
# {'name': 'Consumer Price Index for all Urban Consumers', 'interval': 'monthly', 'unit': 'index 1982-1984=100', 'data': [{'date': '2022-10-01', 'value': '298.012'}, {'date': '2022-09-01', 'value': '296.808'}, {'date': '2022-08-01', 'value': '296.171'}, {'date': '2022-07-01', 'value': '296.276'}, {'date': '2022-06-01', 'value': '296.311'}, {'date': '2022-05-01', 'value': '292.296'}, {'date': '2022-04-01', 'value': '289.109'}, {'date': '2022-03-01', 'value': '287.504'}, {'date': '2022-02-01', 'value': '283.716'}, {'date': '2022-01-01', 'value': '281.148'}, {'date': '2021-12-01', 'value': '278.802'}, {'date': '2021-11-01', 'value': '277.948'}, {'date': '2021-10-01', 'value': '276.589'}, {'date': '2021-09-01', 'value': '274.310'}, {'date': '2021-08-01', 'value': '273.567'}, {'date': '2021-07-01', 'value': '273.003'}, {'date': '2021-06-01', 'value': '271.696'}, {'date': '2021-05-01', 'value': '269.195'}, {'date': '2021-04-01', 'value': '267.054'}, {'date': '2021-03-01', 'value': '264.877'}
# ...

# %%
inflation_data
# This showns inflation data
# Out:
# {'name': 'Consumer Price Index for all Urban Consumers',
#  'interval': 'monthly',
#  'unit': 'index 1982-1984=100',
#  'data': [{'date': '2022-10-01', 'value': '298.012'},
#   {'date': '2022-09-01', 'value': '296.808'},
#   {'date': '2022-08-01', 'value': '296.171'},
#   {'date': '2022-07-01', 'value': '296.276'},
#   {'date': '2022-06-01', 'value': '296.311'},
#   {'date': '2022-05-01', 'value': '292.296'},
#   {'date': '2022-04-01', 'value': '289.109'},
#   {'date': '2022-03-01', 'value': '287.504'},
#   {'date': '2022-02-01', 'value': '283.716'},
#   {'date': '2022-01-01', 'value': '281.148'},
#   {'date': '2021-12-01', 'value': '278.802'},
#   {'date': '2021-11-01', 'value': '277.948'},
#   {'date': '2021-10-01', 'value': '276.589'},
#   {'date': '2021-09-01', 'value': '274.310'},
#   {'date': '2021-08-01', 'value': '273.567'},
#   {'date': '2021-07-01', 'value': '273.003'},
#   {'date': '2021-06-01', 'value': '271.696'},
#   {'date': '2021-05-01', 'value': '269.195'},
# ...

# %% [markdown]
# # Download minute Twitter stock price data from Alphavantage

# %%
CSV_URL = 'https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY_EXTENDED&symbol=TWTR&interval=1min&slice=year2month12& outputsize=full&apikey=KA3WLMAG53VKX67'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)
    for row in my_list:
        print(row)
# Out:
# ['time', 'open', 'high', 'low', 'close', 'volume']
# ['2021-01-06 20:00:00', '52.21', '52.5', '52.2', '52.5', '4108']
# ['2021-01-06 19:59:00', '52.2', '52.35', '52.2', '52.35', '220']
# ['2021-01-06 19:58:00', '52.25', '52.25', '52.25', '52.25', '536']
# ['2021-01-06 19:57:00', '52.19', '52.19', '52.19', '52.19', '412']
# ['2021-01-06 19:56:00', '52.2', '52.2', '52.2', '52.2', '859']
# ['2021-01-06 19:55:00', '52.2', '52.2', '52.2', '52.2', '307']
# ['2021-01-06 19:54:00', '52.17', '52.17', '52.13', '52.17', '442']
# ['2021-01-06 19:53:00', '52.15', '52.17', '52.15', '52.17', '336']
# ['2021-01-06 19:50:00', '52.2', '52.2', '52.17', '52.17', '250']
# ['2021-01-06 19:48:00', '52.18', '52.18', '52.0', '52.0', '6683']
# ['2021-01-06 19:47:00', '52.03', '52.03', '52.03', '52.03', '537']
# ['2021-01-06 19:46:00', '52.3', '52.31', '52.01', '52.01', '7472']
# ['2021-01-06 19:45:00', '52.4', '52.4', '52.4', '52.4', '551']
# ['2021-01-06 19:44:00', '52.38', '52.4', '52.38', '52.4', '1297']
# ...

# %%
len(my_list)
# Out:
# 9486

# %%
url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol=TSLA&apikey=KA3WLMAG53VKX67'
r = requests.get(url)
tesla_earnings_data = r.json()

# %%
tesla_earnings_data
# Out:
# {'symbol': 'TSLA',
#  'annualEarnings': [{'fiscalDateEnding': '2022-09-30', 'reportedEPS': '2.88'},
#   {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '2.26'},
#   {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '1.19'},
#   {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '-0.02'},
#   {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '-5.44'},
#   {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '-8.62'},
#   {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '-3.04'},
#   {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '-2.29'},
#   {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '0.12'},
#   {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '0.77'},
#   {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '-3.22'},
#   {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '-2.21'},
#   {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '-0.8671'}],
#  'quarterlyEarnings': [{'fiscalDateEnding': '2022-09-30',
#    'reportedDate': '2022-10-19',
#    'reportedEPS': '1.05',
# ...

# %%
#print(twitter_earnings_data)
for (key, value) in twitter_earnings_data:
  print (key, value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1464\1896177514.py in <module>
#       1 #print(twitter_earnings_data)
# ----> 2 for (key, value) in twitter_earnings_data:
#       3   print (key, value)
#
# NameError: name 'twitter_earnings_data' is not defined

# %%
# Ticker symbol lookups
url = 'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=tesla&apikey=KA3WLMAG53VKX67'
r = requests.get(url)
tesla_data = r.json()

print(tesla_data)
# Out:
# {'bestMatches': [{'1. symbol': 'TSLA', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8889'}, {'1. symbol': 'TL0.DEX', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'XETRA', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7143'}, {'1. symbol': 'TL0.FRK', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7143'}, {'1. symbol': 'TSLA34.SAO', '2. name': 'Tesla Inc', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.7143'}]}

# %%
import requests

url = 'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords=ftse&apikey=KA3WLMAG53VKX67'
r = requests.get(url)
data = r.json()

print(data)
# Out:
# {'bestMatches': [{'1. symbol': 'FTFX.LON', '2. name': 'FTSE Fledgling ex Investment Trusts', '3. type': 'ETF', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'USD', '9. matchScore': '0.4000'}]}

# %%
#TWTR is the Twitter stock ticker and TSLA for Tesla

# %% [markdown]
# # yfinance data

# %% [markdown]
# The yfinance API to Yahoo finance is also often used in the machine learning literature
# https://finance.yahoo.com/quote/CL=F?p=CL=F&.tsrc=fin-srch
#
# Docs are here in PyPI
# https://pypi.org/project/yfinance/

# %%
# !pip3 install yfinance

# %%
import yfinance as yf

# %%
twitter= yf.Ticker("twtr")

# show actions (dividends, splits)
twitter.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
twitter_hist = twitter.history(period="max")

# %%
twitter_hist.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2013-11-07 00:00:00-05:00  45.099998  50.090000  44.000000  44.900002
# 2013-11-08 00:00:00-05:00  45.930000  46.939999  40.685001  41.650002
# 2013-11-11 00:00:00-05:00  40.500000  43.000000  39.400002  42.900002
# 2013-11-12 00:00:00-05:00  43.660000  43.779999  41.830002  41.900002
# 2013-11-13 00:00:00-05:00  41.029999  42.869999  40.759998  42.599998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2013-11-07 00:00:00-05:00  117701670          0             0
# 2013-11-08 00:00:00-05:00   27925307          0             0
# 2013-11-11 00:00:00-05:00   16113941          0             0
# 2013-11-12 00:00:00-05:00    6316755          0             0
# 2013-11-13 00:00:00-05:00    8688325          0             0

# %%
twitter_hist.tail()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2022-10-21 00:00:00-04:00  50.000000  50.750000  49.549999  49.889999
# 2022-10-24 00:00:00-04:00  50.709999  51.860001  50.520000  51.520000
# 2022-10-25 00:00:00-04:00  52.415001  53.180000  52.200001  52.779999
# 2022-10-26 00:00:00-04:00  52.950001  53.500000  52.770000  53.349998
# 2022-10-27 00:00:00-04:00  53.910000  54.000000  53.700001  53.700001
#
#                               Volume  Dividends  Stock Splits
# Date
# 2022-10-21 00:00:00-04:00   51209029          0             0
# 2022-10-24 00:00:00-04:00   22987553          0             0
# 2022-10-25 00:00:00-04:00   35077848          0             0
# 2022-10-26 00:00:00-04:00   28064973          0             0
# 2022-10-27 00:00:00-04:00  136345128          0             0

# %%
sp= yf.Ticker("^GSPC") # yfinance API for the S and P 500 stock index, ^IXIC is the NASDAQ composite)

# %%
sp_hist=sp.history(period="1d",interval="1m") #,interval=1m means one minute, period is how far back we go)

# %%
sp_hist
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2022-11-17 09:30:00-05:00  3919.260010  3919.260010  3911.060059  3913.610107
# 2022-11-17 09:31:00-05:00  3913.729980  3916.530029  3912.439941  3916.479980
# 2022-11-17 09:32:00-05:00  3916.239990  3917.110107  3914.729980  3917.110107
# 2022-11-17 09:33:00-05:00  3917.139893  3917.560059  3915.530029  3916.189941
# 2022-11-17 09:34:00-05:00  3916.409912  3916.409912  3913.159912  3914.020020
# ...                                ...          ...          ...          ...
# 2022-11-17 13:03:00-05:00  3950.449951  3950.560059  3948.850098  3948.989990
# 2022-11-17 13:04:00-05:00  3948.989990  3949.389893  3948.260010  3948.310059
# 2022-11-17 13:05:00-05:00  3948.239990  3948.239990  3947.280029  3947.330078
# 2022-11-17 13:06:00-05:00  3947.330078  3949.909912  3947.260010  3949.260010
# 2022-11-17 13:07:17-05:00  3949.600098  3949.600098  3949.600098  3949.600098
#
# ...

# %%
wti= yf.Ticker("CL=F") # yfinance API for West Texas Intermediate Crude Oil / NYMEX futures prices

# %%
wti_hist = wti.history(period="max")

# %%
wti_hist.head()
# Out:
#                                 Open       High        Low      Close  Volume  \
# Date
# 2000-08-23 00:00:00-04:00  31.950001  32.799999  31.950001  32.049999   79385
# 2000-08-24 00:00:00-04:00  31.900000  32.240002  31.400000  31.629999   72978
# 2000-08-25 00:00:00-04:00  31.700001  32.099998  31.320000  32.049999   44601
# 2000-08-28 00:00:00-04:00  32.040001  32.919998  31.860001  32.869999   46770
# 2000-08-29 00:00:00-04:00  32.820000  33.029999  32.560001  32.720001   49131
#
#                            Dividends  Stock Splits
# Date
# 2000-08-23 00:00:00-04:00          0             0
# 2000-08-24 00:00:00-04:00          0             0
# 2000-08-25 00:00:00-04:00          0             0
# 2000-08-28 00:00:00-04:00          0             0
# 2000-08-29 00:00:00-04:00          0             0

# %% [markdown]
# # Jupyter Notebooks Finance Demo
# from [pythonanywhere.com](https://blog.pythonanywhere.com127/)
#
# All code and text was authored and shared by [@ConradHo](https://twitter.com/conradho?lang=en)

# %% [markdown]
# The goal of this demo is to show how ipython notebooks can be used in conjunction with different datasources (eg: [Quandl](https://www.quandl.com/) and useful python libraries (eg: pandas) to do financial analysis. It will try to slowly introduce new and useful functions for the new python user.
#
# Since oil-equity corr has been all the talk these days (this demo was written in Jan 2016), let's take a look at it!

# %%
# !pip install --upgrade quandl
# Out:
# ...
#      ---------------------------------------- 52.8/52.8 kB 2.8 MB/s eta 0:00:00
# ...

# %%
import quandl

# %%
quandl.ApiConfig.api_key = "LEP_25DuDUgfrv15Mapy"

# %%
btc=quandl.get('BITFINEX/BTCUSD')

# %%
btc.Last.tail()
# Out:
# Date
# 2022-11-12    16800.0
# 2022-11-13    16343.0
# 2022-11-14    16689.0
# 2022-11-15    16868.0
# 2022-11-16    16645.0
# Name: Last, dtype: float64

# %%
cl=quandl.get('CHRIS/CME_CL1')

# %%
type(cl)
# Out:
# pandas.core.frame.DataFrame

# %%
cl.head()
# Out:
#              Open   High    Low   Last  Change  Settle  Volume  \
# Date
# 1983-03-30  29.01  29.56  29.01  29.40     NaN   29.40   949.0
# 1983-03-31  29.40  29.60  29.25  29.29     NaN   29.29   521.0
# 1983-04-04  29.30  29.70  29.29  29.44     NaN   29.44   156.0
# 1983-04-05  29.50  29.80  29.50  29.71     NaN   29.71   175.0
# 1983-04-06  29.90  29.92  29.65  29.90     NaN   29.90   392.0
#
#             Previous Day Open Interest
# Date
# 1983-03-30                       470.0
# 1983-03-31                       523.0
# 1983-04-04                       583.0
# 1983-04-05                       623.0
# 1983-04-06                       640.0

# %%
cl.tail()
# Out:
#              Open   High    Low   Last  Change  Settle    Volume  \
# Date
# 2021-06-23  72.91  74.25  72.82  73.28    0.23   73.08  422226.0
# 2021-06-24  73.28  73.61  72.32  73.33    0.22   73.30  331826.0
# 2021-06-25  73.32  74.18  72.85  74.00    0.75   74.05  357898.0
# 2021-06-28  73.99  74.45  72.62  72.77   -1.14   72.91  351101.0
# 2021-06-29  72.78  73.81  71.97  73.44    0.07   72.98  318465.0
#
#             Previous Day Open Interest
# Date
# 2021-06-23                    426766.0
# 2021-06-24                    426977.0
# 2021-06-25                    427257.0
# 2021-06-28                    416743.0
# 2021-06-29                    407860.0

# %%
cl.describe()
# Out:
#               Open         High          Low         Last       Change  \
# count  9613.000000  9613.000000  9613.000000  9613.000000  1848.000000
# mean     43.306759    43.906041    42.675150    43.311186     0.872240
# std      27.998630    28.347724    27.610772    27.993730     1.925443
# min     -14.000000    11.020000   -40.320000   -13.100000    -4.600000
# 25%      20.150000    20.360000    19.920000    20.140000     0.260000
# 50%      30.640000    30.880000    30.350000    30.670000     0.650000
# 75%      61.180000    61.900000    60.200000    61.140000     1.210000
# max     145.190000   147.270000   143.220000   145.290000    55.900000
#
#             Settle        Volume  Previous Day Open Interest
# count  9613.000000  9.613000e+03                 9612.000000
# mean     43.308228  1.698697e+05               155337.526113
# std      28.000613  2.045077e+05               140297.493740
# min     -37.630000  0.000000e+00                    0.000000
# ...

# %%
es=quandl.get('CHRIS/CME_ES1') # SP500 index futures settlement prices

# %%
es.tail()
# Out:
#                Open     High      Low     Last  Change   Settle     Volume  \
# Date
# 2021-06-14  4248.00  4257.50  4233.50  4255.00    9.00  4254.75  1089658.0
# 2021-06-15  4255.25  4267.50  4238.00  4247.25   -8.25  4246.50   944668.0
# 2021-06-16  4248.00  4251.25  4200.75  4212.75  -23.50  4223.00   482760.0
# 2021-06-17  4214.25  4232.50  4193.00  4225.75   -0.75  4222.25   305144.0
# 2021-06-18  4225.75  4231.00  4183.75  4185.50     NaN  4187.25    35117.0
#
#             Previous Day Open Interest
# Date
# 2021-06-14                   1833460.0
# 2021-06-15                   1265301.0
# 2021-06-16                    744020.0
# 2021-06-17                    590729.0
# 2021-06-18                    539808.0

# %%
es.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1464\1425522919.py in <module>
# ----> 1 es.describe()
#
# NameError: name 'es' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
es.to_csv("/content/drive/MyDrive/Colab Notebooks/es_spx_futures.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1464\1752381844.py in <module>
# ----> 1 es.to_csv("/content/drive/MyDrive/Colab Notebooks/es_spx_futures.csv")
#
# NameError: name 'es' is not defined

# %%
cl.to_csv("/content/drive/MyDrive/Colab Notebooks/cl_oil_futures.csv")

# %%
#select rows with missing values
es[es['Open'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Last, Change, Settle, Volume, Previous Day Open Interest]
# Index: []

# %%
cl[cl['Open'].isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Last, Change, Settle, Volume, Previous Day Open Interest]
# Index: []

# %%
es_close=es.Settle
cl_close=cl.Settle

# %%
es_close.describe()
# Out:
# count    6069.00000
# mean     1647.06707
# std       726.80853
# min       676.00000
# 25%      1144.00000
# 50%      1354.75000
# 75%      2040.50000
# max      4254.75000
# Name: Settle, dtype: float64

# %% [markdown]
# es_close is Panda series of numpy.float64 values

# %%
print(type(es))
print(type(es_close))
print(type(es_close[0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'numpy.float64'>

# %%
earliest_es_date=es_close.index[0]
earliest_cl_date=cl_close.index[0]
print("earliest_es_date=",earliest_es_date)
print("earliest_cl_date=",earliest_cl_date)
# Out:
# earliest_es_date= 1997-09-09 00:00:00
# earliest_cl_date= 1983-03-30 00:00:00

# %%
cl_close[earliest_cl_date:].head()
# Out:
# Date
# 1983-03-30    29.40
# 1983-03-31    29.29
# 1983-04-04    29.44
# 1983-04-05    29.71
# 1983-04-06    29.90
# Name: Settle, dtype: float64

# %%
es_close[earliest_es_date:].head()
# Out:
# Date
# 1997-09-09    934.0
# 1997-09-10    915.0
# 1997-09-11    908.0
# 1997-09-12    924.0
# 1997-09-15    922.0
# Name: Settle, dtype: float64

# %%
cl_close[earliest_es_date:].head()
# Out:
# Date
# 1997-09-09    19.42
# 1997-09-10    19.42
# 1997-09-11    19.37
# 1997-09-12    19.32
# 1997-09-15    19.27
# Name: Settle, dtype: float64

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import matplotlib.dates as mdates
from matplotlib.ticker import FormatStrFormatter, StrMethodFormatter

# %%
plt.plot(es_close.values,'b',label='SP500')
plt.plot(cl_close.values,'k',label='WTI')
plt.yscale('log')

plt.legend()
plt.show()

# %%
fig, ax1 = plt.subplots()

color = 'tab:red'

ax1.set_xlabel('date')

#ax1.yaxis.set_major_formatter(StrMethodFormatter('{x:,}'))
ax1.yaxis.set_major_formatter(StrMethodFormatter('{x:,f}'))
ax1.set_yscale('log')

ax1.set_ylabel('SPX', color=color)


ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%q'))
ax1.plot(es_close[earliest_es_date:], color=color)
ax1.tick_params(axis='y', labelcolor=color)


ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('WTI', color=color)  # we already handled the x-label with ax1
ax2.plot(cl_close[earliest_es_date:],color=color)
ax2.tick_params(axis='y', labelcolor=color)

#fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
es_close.values[:20]
# Out:
# array([934.  , 915.  , 908.  , 924.  , 922.  , 947.  , 946.  , 948.  ,
#        961.  , 966.25, 962.  , 954.5 , 946.5 , 953.25, 961.75, 954.5 ,
#        963.5 , 969.  , 975.5 , 980.25])

# %%
es_close[earliest_es_date:]
# Out:
# Date
# 1997-09-09     934.00
# 1997-09-10     915.00
# 1997-09-11     908.00
# 1997-09-12     924.00
# 1997-09-15     922.00
#                ...
# 2021-06-14    4254.75
# 2021-06-15    4246.50
# 2021-06-16    4223.00
# 2021-06-17    4222.25
# 2021-06-18    4187.25
# Name: Settle, Length: 6069, dtype: float64

# %%
raw_correlation=cl_close[earliest_es_date:].corr(es_close[earliest_es_date:])
print("Raw correlation = {:.2%}".format(raw_correlation))
# Out:
# Raw correlation = 7.54%

# %%
rolling_correlation=es_close[earliest_es_date:].rolling(252).corr(cl_close[earliest_es_date:])

# %%
rolling_correlation[rolling_correlation.isnull()]
# Out:
# Date
# 1997-09-09   NaN
# 1997-09-10   NaN
# 1997-09-11   NaN
# 1997-09-12   NaN
# 1997-09-15   NaN
#               ..
# 2021-06-23   NaN
# 2021-06-24   NaN
# 2021-06-25   NaN
# 2021-06-28   NaN
# 2021-06-29   NaN
# Name: Settle, Length: 4421, dtype: float64

# %%
pd.set_option('max_rows', 99999)
rolling_correlation

# %%
print(len(es_close))
print(len(cl_close))
# Out:
# 6069
# 9613

# %%
merged = pd.concat({'es': es_close, 'cl': cl_close}, axis=1)
# maybe this is the culprit?
merged[merged['cl'].isnull()].head()
# Out:
#                  es  cl
# Date
# 1997-11-27   959.50 NaN
# 1997-11-28   955.00 NaN
# 1998-01-19   972.25 NaN
# 1998-02-16  1019.00 NaN
# 1998-05-25  1116.50 NaN

# %%
len(merged[merged['cl'].isnull()])
# Out:
# 92

# %%
merged.dropna(how='any', inplace=True)

# %%
print(merged)
# Out:
#                  es      cl
# Date
# 1997-09-09   934.00   19.42
# 1997-09-10   915.00   19.42
# 1997-09-11   908.00   19.37
# 1997-09-12   924.00   19.32
# 1997-09-15   922.00   19.27
# 1997-09-16   947.00   19.61
# 1997-09-17   946.00   19.42
# 1997-09-18   948.00   19.38
# 1997-09-19   961.00   19.35
# 1997-09-22   966.25   19.60
# 1997-09-23   962.00   19.79
# 1997-09-24   954.50   19.94
# 1997-09-25   946.50   20.39
# 1997-09-26   953.25   20.87
# 1997-09-29   961.75   21.26
# 1997-09-30   954.50   21.18
# 1997-10-01   963.50   21.05
# 1997-10-02   969.00   21.77
# 1997-10-03   975.50   22.76
# 1997-10-06   980.25   21.93
# 1997-10-07   989.50   21.96
# 1997-10-08   982.25   22.18
# 1997-10-09   978.00   22.12
# 1997-10-10   976.75   22.10
# 1997-10-13   976.25   21.32
# 1997-10-14   977.50   20.70
# 1997-10-15   973.50   20.57
# 1997-10-16   959.75   20.97
# 1997-10-17   948.75   20.59
# 1997-10-20   962.25   20.70
# 1997-10-21   979.50   20.67
# 1997-10-22   974.25   21.42
# ...

# %%
merged[merged['cl'].isnull()]
# Out:
# Empty DataFrame
# Columns: [es, cl]
# Index: []

# %% [markdown]
# All the bad data where there are no matching values is gone!

# %%
rolling_correlation=merged.es.rolling(252).corr(merged.cl).dropna()
rolling_correlation.plot(color='b')

plt.axhline(0, color='k')
rolling_correlation=es_close[earliest_es_date:].rolling(252).corr(cl_close[earliest_es_date:])

# %% [markdown]
# Take the first differences of the stock returns

# %%
print('Autocorrelation for S&P is {:.3%}'.format(es_close.autocorr()))
# Out:
# Autocorrelation for S&P is 99.960%

# %%
daily_returns = merged.pct_change()
rolling_correlation=daily_returns.es.rolling(252).corr(daily_returns.cl)
rolling_correlation.plot(color='b')
plt.axhline(0, color='k')
plt.title('Rolling 1 yr correlation between Oil and S&P')
# Out:
# Text(0.5, 1.0, 'Rolling 1 yr correlation between Oil and S&P')

# %% [markdown]
# Great. Now this is much more interesting. It is quite clear that the period of higher correlation in oil prices came after 2009. Qualitatively, we know (if you worked in finance back then) that this was the case: previously, extreme high oil prices (over $100/bbl) were seen as a drag on the economy. Nowadays, extreme low oil prices are seen as an indication of weakness in global demand, with oil prices, equity, credit etc all selling off hand in hand when there is risk off sentiment.

# %% [markdown]
# Let's plot some pretty graphs to show what we know qualitatively, and make sure our memory was correct.

# %%
from matplotlib.ticker import MaxNLocator

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
fig.suptitle('Checking our intuition about correlation', fontsize=14, fontweight='bold')
# make space for the title
fig.subplots_adjust(top=0.85)

rolling_correlation.plot(ax=ax1)
ax1.set_title('Rolling correlation of WTI returns vs S&P returns')
ax1.axhline(0, color='k')
ax1.tick_params(
    which='both',  # both major and minor ticks
    bottom='off', top='off', right='off',
    labelbottom='off'  # labels along the bottom edge are off
)

cl_close.plot(ax=ax2)
ax2.set_title('Price of front month WTI crude')
ax2.tick_params(which='both', top='off', right='off')
ax2.tick_params(which='minor', bottom='off')
ax2.yaxis.set_major_locator(MaxNLocator(5)) # how many ticks

# %% [markdown]
# Alright, fine. So we can distinctly see the regime change starting from the European debt crisis, when oil came back down from $150/bbl. Traders no longer saw high oil prices as a drag on the economy, and instead focused on their intention on global demand instead as we entered a period of slow growth.
#
# Also, all the recent talk about equity oil correlation, we have actually seen higher correlations in the 2011-2013 period.
#
# So this is an interesting observation. But as data scientists, we must test this hypothesis! If the cause of this recent spike in equity/crude corr is really driven by risk off sentiment, let's see if there is also much stronger cross asset correlation in other risk assets. Stay tuned for the next part of this series!
